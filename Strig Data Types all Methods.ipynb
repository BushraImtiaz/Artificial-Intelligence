# %%
a = "bushra imtiaz"
print (a)
print(a.capitalize())
# Out:
# bushra imtiaz
# Bushra imtiaz

# %%
a = "bushra imtiaz"
print (a)
print(a.center(50))
# Out:
# bushra imtiaz
#                   bushra imtiaz

# %%
a = "bushra imtiaz"
print (a)
print(a.center(50))
# Out:
# bushra imtiaz
#                   bushra imtiaz

# %%
a = [1,1,1,1,4,2,4,55,6,7]
print (a)
print(a.count(1))
# Out:
# [1, 1, 1, 1, 4, 2, 4, 55, 6, 7]
# 4

# %%
a = "bushra imtiaz"
print (a)
print(a.encode())
# Out:
# bushra imtiaz
# b'bushra imtiaz'

# %%
str = "My name is bushra imtiaz!!"
suffix = "imtiaz!!"
print (str)
print (str.endswith(suffix))
# Out:
# My name is bushra imtiaz!!
# True

# %%
str = 'xyz\t12345\tabc'
print(str)
print(str.expandtabs(16))
# Out:
# xyz	12345	abc
# xyz             12345           abc

# %%
s = 'abcd1234dcba'

print(s.find('1234')) 
print(s.find('234'))
print(s.find('34'))
print(s.find('4'))
# Out:
# 4
# 5
# 6
# 7

# %%
str = "my name is {}"
print (str.format("bushra"))

str = "my age is {}"
print("type your age!")
age = input()
print (str.format(age))
# Out:
# my name is bushra
# type your age!
# 34
# my age is 34

# %%
point = {'x':4,'y':-5}
print('{x} {y}'.format_map(point))
# Out:
# 4 -5

# %%
vowels = ['a', 'e', 'i', 'o', 'i', 'u']
# index of 'e'
index = vowels.index('e')
print('The index of e:', index)
# Out:
# The index of e: 1

# %%
str = "aeiou"
print(str.isalnum())
# Out:
# True

# %%
str = "aeiou"
print(str.isalpha())
# Out:
# True

# %%
str = "456879"
print(str.isdecimal())
# Out:
# True

# %%
str = "456879"
print(str.isdigit())
# Out:
# True

# %%
str = "validString"
print(str.isidentifier())

str = "IN validString"
print(str.isidentifier())
# Out:
# True
# False

# %%
str = 'hollywood'
print(str.islower())
# Out:
# True

# %%
str = '01234568461321'
print(str.isnumeric())

str = '01234568461a321'
print(str.isnumeric())
# Out:
# True
# False

# %%
str = '01234568461321'
print(str.isprintable())

str = '\n 01234568461321rgsdfg'
print(str.isprintable())
# Out:
# True
# False

# %%
str = ' '
print(str.isspace())
# Out:
# True

# %%
str = 'bushra'
print(str.istitle())

str = 'bushra'
print(str.istitle())
# Out:
# False
# False

# %%
str = 'bushra'
print(str.isupper())

str = 'bushra'
print(str.isupper())
# Out:
# False
# False

# %%
str = 'bushra imtiaz'
s = '-'
print(s.join(str))
# Out:
# b-u-s-h-r-a- -i-m-t-i-a-z

# %%
str = "....wow!!!";
print (str.ljust(50, '0'))
# Out:
# ....wow!!!0000000000000000000000000000000000000000

# %%
str = 'bushra'
print(str.lower())
# Out:
# bushra

# %%
str = '    bushra imtiaz'
print(str)
print(str.lstrip())
# Out:
#     bushra imtiaz
# bushra imtiaz

# %%
dict = {"a": "123", "b": "456", "c": "789"}
string = "abc"
print(string.maketrans(dict))

firstString = "abc"
secondString = "def"
string = "abc"
print(string.maketrans(firstString, secondString))
# Out:
# {97: '123', 98: '456', 99: '789'}
# {97: 100, 98: 101, 99: 102}

# %%
str = 'bushra imtiaz'
seperator = ' '
print(str)
print(str.partition(seperator))
# Out:
# bushra imtiaz
# ('bushra', ' ', 'imtiaz')

# %%
str = 'bushra imtiaz'
print(str)
print(str.replace('imtiaz','IMTIAZ',1))
# Out:
# bushra imtiaz
# bushra IMTIAZ

# %%
quote = 'Let it be, let it be, let it be'

result = quote.rfind('let it')
print("Substring 'let it':", result)
# Out:
# Substring 'let it': 22

# %%
quote = 'Let it be, let it be, let it be'

result = quote.rindex('let it')
print("Substring 'let it':", result)
# Out:
# Substring 'let it': 22

# %%
str = "!!!wow!!!";
print (str.rjust(50, '*'))
# Out:
# *****************************************!!!wow!!!

# %%
str = 'my name is bushra'
print(str.rpartition("is"))
# Out:
# ('my name ', 'is', ' bushra')

# %%
str = 'my name is bushra                               '
print(str)
print(str.rstrip())
# Out:
# my name is bushra
# my name is bushra

# %%
str = 'my name is bushra'
print(str.split("is"))
# Out:
# ['my name ', ' bushra']

# %%
str = 'my name is \n bushra'
print(str)
print(str.splitlines(5))
# Out:
# my name is
#  bushra
# ['my name is \n', ' bushra']

# %%
str = 'my name is bushra'
print(str.startswith("my"))
# Out:
# True

# %%
str = '                               my name is bushra                                    '
print(str)
print(str.strip())
# Out:
#                                my name is bushra
# my name is bushra

# %%
str = 'my name is bushra'
print(str.swapcase())
# Out:
# MY NAME IS BUSHRA

# %%
str = 'my name is bushra'
print(str.title())
# Out:
# My Name Is Bushra

# %%
# Python 3 Program to show working 
# of translate() method 
  
# specifying the mapping   
# using ASCII   
translation = {103: None, 101: None, 101: None} 
  
string = "geeks"
print("Original string:", string) 
  
# translate string 
print("Translated string:",  
       string.translate(translation))
# Out:
# Original string: geeks
# Translated string: ks

# %%
str = 'my name is bushra'
print(str.upper())
# Out:
# MY NAME IS BUSHRA

# %%
str =  ' my name is bushra'
print(str.zfill(50))
# Out:
# 00000000000000000000000000000000 my name is bushra

# %% [markdown]
# Applying Random Operators on 20 Opperands

# %%
9+8*2/2**2+(7-3)*7
# Out:
# 41.0

# %%
9+8*2/2*7
# Out:
# 65.0

# %%
9+(7-3)*7
# Out:
# 37

# %%
10+800*2/4**2+(51-3)*7
# Out:
# 446.0

# %%
10+800*2/4**2+(51-3)*7
# Out:
# 446.0

# %%
10+800*7
# Out:
# 5610

# %%
2/4**2+(51-3)*7
# Out:
# 336.125

# %%
10+800*2/4**7
# Out:
# 10.09765625

# %%
10+80*2/4**7
# Out:
# 10.009765625

# %%
10-20*0-800*2/4**7
# Out:
# 9.90234375

# %%
5/4*4+45+1/5+5**4
# Out:
# 675.2

# %%
186*4-41**4+464
# Out:
# -2824553

# %%
59**6-46+0
# Out:
# 42180533595

# %%
10+800*2/4*4*4*4*7
# Out:
# 179210.0

# %%
10+800*2/4*4/4+5+9+8-7-0
# Out:
# 425.0

# %%
464/464*464-464+5645**4
# Out:
# 1015443549300625.0

# %%
54325*524*-25254413+441234123/4
# Out:
# -718899586473369.2

# %%
5+5+5/2
# Out:
# 12.5

# %%
4/4+1-2
# Out:
# 0.0
