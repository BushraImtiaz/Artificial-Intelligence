# %% [markdown]
# AI batch 4 class 1 assignment solution

# %%
name = "Bushra Imtiaz"
age = 18
clas = "Artificial Intelligence"
university = "PIAIC Karachi"
print(f"Hello {name} your application is accepted for {clas} in {university}")
# Out:
# Hello Bushra Imtiaz your application is accepted for Artificial Intelligence in PIAIC Karachi

# %%
cities=["Faisalabad","Islamabad","Karachi","Lahore","Quetta"]
result=[93.4, 95, 98.7, 87.4, 83.02]
score=[45, 70, 54, 90, 42]
print(*cities)
print(*result)
print(*score)
# Out:
# Faisalabad Islamabad Karachi Lahore Quetta
# 93.4 95 98.7 87.4 83.02
# 45 70 54 90 42

# %% [markdown]
# OR

# %%
cities=["Faisalabad","Islamabad","Karachi","Lahore","Quetta"]
result=[93.4, 95, 98.7, 87.4, 83.02]
score=[45, 70, 54, 90, 42]
print(f"""{cities}
{result}
{score}""")
# Out:
# ['Faisalabad', 'Islamabad', 'Karachi', 'Lahore', 'Quetta']
# [93.4, 95, 98.7, 87.4, 83.02]
# [45, 70, 54, 90, 42]

# %% [markdown]
# Class for Week 1 of Python
# Here is code notebook for class 1. You can practice it.
#
# Assignment
# Your first assignment is to write code for formatting string.
#
# Store data of a person in four variables such as name, age, class, university. Use formatting to output such results.
#
# Hello 'Ali Raza'
# Your application is accepted for Artificial Intelligence in UNIVERSITY_NAME
# Note
# Output can vary according to your values in variables.

# %% [markdown]
# name = "Bushra Imtiaz"
# age = 18
# clas = "Artificial Intelligence"
# university = "PIAIC Karachi"
# print(f"Hello {name} your application is accepted for {clas} in {university}")
#
#
# 							OR
#
#
# Class 1
# (solution)
#
# name="your name"
# age=21
# className="AI"
# uni="your university name"
#
# message="""Hello {u_name} \nage {u_age}\nYour application is accepted for {u_class_name} at {u_uni}""".format(u_name=name, u_age=age, u_class_name=className, u_uni=uni)
#
# print(message)
