# %%
import pandas as pd
import numpy as np
import re

# %%
students = [{
    'Name': 'Inam',
    'Age': 42
},
{
    'Name': 'Ali',
    'Age': 22,
    'Course': 'AI'
},{
    'Name': 'Daniyal',
    'Age': 42,
    'Course': 'CNCF'
},{
    'Name': 'Mohsin',    
    'Course': 'CNCF'
},{
    'Name': 'Aamir',
    'Age': 22
},{
    'Name': 'Aamir',
    'Age': 22
},{
    'Name': 'Aamir',
    'Age': 22,
    'Course': 'CNCF'
}]

# %%
students_df = pd.DataFrame(students)
students_df
# Out:
#       Name   Age Course
# 0     Inam  42.0    NaN
# 1      Ali  22.0     AI
# 2  Daniyal  42.0   CNCF
# 3   Mohsin   NaN   CNCF
# 4    Aamir  22.0    NaN
# 5    Aamir  22.0    NaN
# 6    Aamir  22.0   CNCF

# %%
pd.value_counts(students_df['Course'])
# Out:
# CNCF    3
# AI      1
# Name: Course, dtype: int64

# %%
students_df.notnull()
# Out:
#    Name    Age  Course
# 0  True   True   False
# 1  True   True    True
# 2  True   True    True
# 3  True  False    True
# 4  True   True   False
# 5  True   True   False
# 6  True   True    True

# %%
dropped_df = students_df.dropna()
dropped_df
# Out:
#       Name   Age Course
# 1      Ali  22.0     AI
# 2  Daniyal  42.0   CNCF
# 6    Aamir  22.0   CNCF

# %%
students_df
# Out:
#       Name   Age Course
# 0     Inam  42.0    NaN
# 1      Ali  22.0     AI
# 2  Daniyal  42.0   CNCF
# 3   Mohsin   NaN   CNCF
# 4    Aamir  22.0    NaN
# 5    Aamir  22.0    NaN
# 6    Aamir  22.0   CNCF

# %%
filled_df = students_df.fillna({'Age': students_df['Age'].mean(), 'Course': 'Un-Known'})
filled_df
# Out:
#       Name        Age    Course
# 0     Inam  42.000000  Un-Known
# 1      Ali  22.000000        AI
# 2  Daniyal  42.000000      CNCF
# 3   Mohsin  28.666667      CNCF
# 4    Aamir  22.000000  Un-Known
# 5    Aamir  22.000000  Un-Known
# 6    Aamir  22.000000      CNCF

# %%
filled_df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
droped_dup_df = filled_df.drop_duplicates(keep='last')
droped_dup_df
# Out:
#       Name        Age    Course
# 0     Inam  42.000000  Un-Known
# 1      Ali  22.000000        AI
# 2  Daniyal  42.000000      CNCF
# 3   Mohsin  28.666667      CNCF
# 5    Aamir  22.000000  Un-Known
# 6    Aamir  22.000000      CNCF

# %%
twice_age = droped_dup_df['Age'].map(lambda val: val * 2)
twice_age
# Out:
# 0    84.000000
# 1    44.000000
# 2    84.000000
# 3    57.333333
# 5    44.000000
# 6    44.000000
# Name: Age, dtype: float64

# %%
data = pd.DataFrame(np.arange(12).reshape((3, 4)), index=['Ohio', 'Colorado', 'New York'], 
            columns=['one', 'two', 'three', 'four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
data = data.rename(index=str.title, columns=str.upper)
data
# Out:
#           ONE  TWO  THREE  FOUR
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# New York    8    9     10    11

# %%
ages = [20, 22, 25, 27, 21, 23, 37, 31, 61, 45, 41, 32]
bins = [18, 25, 35, 60, 100]
group_names = ['Youth', 'YoungAdult', 'MiddleAged', 'Senior']

# %%
freq_group = pd.cut(ages, bins, labels=group_names)
freq_group
# Out:
# [Youth, Youth, Youth, YoungAdult, Youth, ..., YoungAdult, Senior, MiddleAged, MiddleAged, YoungAdult]
# Length: 12
# Categories (4, object): [Youth < YoungAdult < MiddleAged < Senior]

# %%
freq_group.categories
# Out:
# Index(['Youth', 'YoungAdult', 'MiddleAged', 'Senior'], dtype='object')

# %%
freq_group.codes
# Out:
# array([0, 0, 0, 1, 0, 0, 2, 1, 3, 2, 2, 1], dtype=int8)

# %%
pd.value_counts(freq_group)
# Out:
# Youth         5
# MiddleAged    3
# YoungAdult    3
# Senior        1
# dtype: int64

# %%
df = pd.DataFrame(np.arange(5 * 4).reshape((5, 4)))
sampler = np.random.permutation(3)
sampler
# Out:
# array([1, 2, 0])

# %%
sampler = np.random.permutation(3)
df.take(sampler)
# Out:
#    0  1   2   3
# 2  8  9  10  11
# 1  4  5   6   7
# 0  0  1   2   3

# %%
df.sample(n=3)
# Out:
#     0   1   2   3
# 2   8   9  10  11
# 3  12  13  14  15
# 0   0   1   2   3

# %%
students_df
# Out:
#       Name   Age Course
# 0     Inam  42.0    NaN
# 1      Ali  22.0     AI
# 2  Daniyal  42.0   CNCF
# 3   Mohsin   NaN   CNCF
# 4    Aamir  22.0    NaN
# 5    Aamir  22.0    NaN
# 6    Aamir  22.0   CNCF

# %%
students_df.join(pd.get_dummies(students_df['Course']))
# Out:
#       Name   Age Course  AI  CNCF
# 0     Inam  42.0    NaN   0     0
# 1      Ali  22.0     AI   1     0
# 2  Daniyal  42.0   CNCF   0     1
# 3   Mohsin   NaN   CNCF   0     1
# 4    Aamir  22.0    NaN   0     0
# 5    Aamir  22.0    NaN   0     0
# 6    Aamir  22.0   CNCF   0     1

# %%
students_df['Name'].map(str.upper)
# Out:
# 0       INAM
# 1        ALI
# 2    DANIYAL
# 3     MOHSIN
# 4      AAMIR
# 5      AAMIR
# 6      AAMIR
# Name: Name, dtype: object

# %%
emailids = 'inam@hotmail.com, inampaki@yahoo.com, inamsdhhs, basit#.com' 
pattern = r'[A-Z0-9._%+-]+@[A-Z0-9.-]+\.[A-Z]{2,4}'
regex = re.compile(pattern, flags=re.IGNORECASE)

# %%
regex.findall(emailids)
# Out:
# ['inam@hotmail.com', 'inampaki@yahoo.com']

# %%
students_df['Name_In_Caps'] = students_df['Name'].str.upper()

# %%
students_df
# Out:
#       Name   Age Course Name_In_Caps
# 0     Inam  42.0    NaN         INAM
# 1      Ali  22.0     AI          ALI
# 2  Daniyal  42.0   CNCF      DANIYAL
# 3   Mohsin   NaN   CNCF       MOHSIN
# 4    Aamir  22.0    NaN        AAMIR
# 5    Aamir  22.0    NaN        AAMIR
# 6    Aamir  22.0   CNCF        AAMIR
